# %%
import pandas as pd
import os

# %%
import librosa

# %%
Tess = "C:/Users/Admin/Desktop/New folder (4)/birds audio detection/model/dataset/Tess/"

# %%
tess_directory_list = os.listdir(Tess)

file_emotion = []
file_path = []

for dir in tess_directory_list:
    directories = os.listdir(Tess + dir)
    for file in directories:
        part = file.split('.')[0]
        part = part.split('_')[2]
        if part=='ps':
            file_emotion.append('surprise')
        else:
            file_emotion.append(part)
        file_path.append(Tess + dir + '/' + file)
        
# dataframe for emotion of files
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])

# dataframe for path of files.
path_df = pd.DataFrame(file_path, columns=['Path'])
Tess_df = pd.concat([emotion_df, path_df], axis=1)
Tess_df.head()
# Out:
#   Emotions                                               Path
# 0    angry  C:/Users/Admin/Desktop/New folder (4)/birds au...
# 1    angry  C:/Users/Admin/Desktop/New folder (4)/birds au...
# 2    angry  C:/Users/Admin/Desktop/New folder (4)/birds au...
# 3    angry  C:/Users/Admin/Desktop/New folder (4)/birds au...
# 4    angry  C:/Users/Admin/Desktop/New folder (4)/birds au...

# %%
Tess_df['Emotions'].value_counts()
# Out:
# angry       400
# disgust     400
# fear        400
# happy       400
# neutral     400
# surprise    400
# sad         400
# Name: Emotions, dtype: int64

# %%
def features_extractor(file):
    audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
    
    return mfccs_scaled_features

# %%
import numpy as np
from tqdm import tqdm
### Now we iterate through every audio file and extract features 
### using Mel-Frequency Cepstral Coefficients
extracted_features=[]
for index_num,row in tqdm(Tess_df.iterrows()):
    file_name = os.path.join(os.path.abspath(Tess),str(row["Path"]))
    final_class_labels=row["Emotions"]
    data=features_extractor(file_name)
    extracted_features.append([data,final_class_labels])
# Out:
# 2800it [01:27, 31.97it/s]

# %%
extracted_features_df=pd.DataFrame(extracted_features,columns=['Path','Emotions'])
extracted_features_df.head()
# Storing the dataframe to pickle for further processing
extracted_features_df.to_pickle("extracted_df.pkl")
extracted_features_df.head()
# Out:
#                                                 Path Emotions
# 0  [-386.65387, 57.02423, -22.126987, -7.373469, ...    angry
# 1  [-447.8823, 70.02029, -7.251139, -15.752107, -...    angry
# 2  [-406.17514, 31.89866, -10.602405, 5.086764, -...    angry
# 3  [-387.20657, 57.649464, -16.744616, -8.857875,...    angry
# 4  [-401.65063, 56.30817, -1.0354272, 12.937799, ...    angry

# %%
final = pd.read_pickle("./extracted_df.pkl")
X = np.array(final["Path"].tolist())
y = np.array(final["Emotions"].tolist())

# %%
        import IPython.display as ipd
        import librosa
        import librosa.display
        import pandas as pd
        import os, time, warnings
        import seaborn as sns
        import numpy as np
        from tqdm import tqdm
        import matplotlib.pyplot as plt
        from sklearn.model_selection import train_test_split
        from sklearn.preprocessing import LabelEncoder
        from tensorflow.keras.utils import to_categorical
        from tensorflow.keras.models import Sequential
        from tensorflow.keras.layers import (
            Dense,
            Conv1D,
            MaxPooling1D,
            BatchNormalization,
            Dropout, 
            Flatten,
            Conv2D,
            MaxPool2D,
        )

# %%
le = LabelEncoder()

# transform each category with it's respected label
Y = to_categorical(le.fit_transform(y))

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=0.1, random_state=42
)

# print the details
print("Number of training samples = ", X_train.shape[0])
print("Number of testing samples = ", X_test.shape[0])
# Out:
# Number of training samples =  2520
# Number of testing samples =  280

# %%
num_labels = Y.shape[1]
ANN_Model = Sequential()
ANN_Model.add(Dense(1000, activation="relu", input_shape=(40,)))
ANN_Model.add(Dense(750, activation="relu"))
ANN_Model.add(Dense(500, activation="relu"))
ANN_Model.add(Dense(250, activation="relu"))
ANN_Model.add(Dense(100, activation="relu"))
ANN_Model.add(Dense(50, activation="relu"))
ANN_Model.add(Dense(num_labels, activation="softmax"))
ANN_Model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1000)              41000
#
#  dense_1 (Dense)             (None, 750)               750750
#
#  dense_2 (Dense)             (None, 500)               375500
#
#  dense_3 (Dense)             (None, 250)               125250
#
#  dense_4 (Dense)             (None, 100)               25100
#
#  dense_5 (Dense)             (None, 50)                5050
#
#  dense_6 (Dense)             (None, 7)                 357
#
# =================================================================
# Total params: 1,323,007
# Trainable params: 1,323,007
# Non-trainable params: 0
# _________________________________________________________________

# %%
ANN_Model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')

# %%
num_epochs = 100
num_batch_size = 32

t0 = time.time()

history = ANN_Model.fit(
    X_train,
    y_train,
    batch_size=num_batch_size,
    epochs=num_epochs,
    validation_data=(X_test, y_test),
)

ANN_Model.save("Model1.h5")
print("ANN Model Saved")
# Out:
# Epoch 1/100
# 79/79 [==============================] - 2s 13ms/step - loss: 2.7386 - accuracy: 0.4127 - val_loss: 0.6980 - val_accuracy: 0.7357
# Epoch 2/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.4353 - accuracy: 0.8413 - val_loss: 0.2203 - val_accuracy: 0.9357
# Epoch 3/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.2290 - accuracy: 0.9226 - val_loss: 0.2305 - val_accuracy: 0.9107
# Epoch 4/100
# 79/79 [==============================] - 1s 11ms/step - loss: 0.1037 - accuracy: 0.9639 - val_loss: 0.0862 - val_accuracy: 0.9750
# Epoch 5/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0755 - accuracy: 0.9722 - val_loss: 0.0616 - val_accuracy: 0.9786
# Epoch 6/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0531 - accuracy: 0.9853 - val_loss: 0.1100 - val_accuracy: 0.9536
# Epoch 7/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0917 - accuracy: 0.9647 - val_loss: 0.0525 - val_accuracy: 0.9821
# Epoch 8/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0501 - accuracy: 0.9825 - val_loss: 0.0520 - val_accuracy: 0.9821
# Epoch 9/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0514 - accuracy: 0.9817 - val_loss: 0.0608 - val_accuracy: 0.9750
# Epoch 10/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0456 - accuracy: 0.9829 - val_loss: 0.0389 - val_accuracy: 0.9857
# Epoch 11/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0210 - accuracy: 0.9921 - val_loss: 0.0437 - val_accuracy: 0.9821
# Epoch 12/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0423 - accuracy: 0.9849 - val_loss: 0.0620 - val_accuracy: 0.9786
# Epoch 13/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0324 - accuracy: 0.9893 - val_loss: 0.1647 - val_accuracy: 0.9500
# Epoch 14/100
# 79/79 [==============================] - 1s 11ms/step - loss: 0.0397 - accuracy: 0.9869 - val_loss: 0.1208 - val_accuracy: 0.9679
# Epoch 15/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0466 - accuracy: 0.9837 - val_loss: 0.0455 - val_accuracy: 0.9857
# Epoch 16/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0273 - accuracy: 0.9913 - val_loss: 0.0397 - val_accuracy: 0.9857
# Epoch 17/100
# 79/79 [==============================] - 1s 14ms/step - loss: 0.0211 - accuracy: 0.9913 - val_loss: 0.0407 - val_accuracy: 0.9893
# Epoch 18/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0608 - accuracy: 0.9821 - val_loss: 0.0389 - val_accuracy: 0.9893
# Epoch 19/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0304 - accuracy: 0.9925 - val_loss: 0.0379 - val_accuracy: 0.9857
# Epoch 20/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0245 - accuracy: 0.9897 - val_loss: 0.0456 - val_accuracy: 0.9893
# Epoch 21/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0091 - accuracy: 0.9968 - val_loss: 0.0256 - val_accuracy: 0.9929
# Epoch 22/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0064 - accuracy: 0.9968 - val_loss: 0.0173 - val_accuracy: 0.9893
# Epoch 23/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0022 - accuracy: 0.9992 - val_loss: 0.0157 - val_accuracy: 0.9929
# Epoch 24/100
# 79/79 [==============================] - 1s 12ms/step - loss: 7.4468e-04 - accuracy: 0.9996 - val_loss: 0.0314 - val_accuracy: 0.9857
# Epoch 25/100
# 79/79 [==============================] - 1s 11ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0188 - val_accuracy: 0.9929
# Epoch 26/100
# 79/79 [==============================] - 1s 11ms/step - loss: 0.0114 - accuracy: 0.9956 - val_loss: 0.0219 - val_accuracy: 0.9893
# Epoch 27/100
# 79/79 [==============================] - 1s 11ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.0350 - val_accuracy: 0.9893
# Epoch 28/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0044 - accuracy: 0.9988 - val_loss: 0.1659 - val_accuracy: 0.9607
# Epoch 29/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0349 - accuracy: 0.9909 - val_loss: 0.0410 - val_accuracy: 0.9821
# Epoch 30/100
# 79/79 [==============================] - 1s 11ms/step - loss: 0.0223 - accuracy: 0.9917 - val_loss: 0.0111 - val_accuracy: 0.9964
# Epoch 31/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.0681 - val_accuracy: 0.9821
# Epoch 32/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0279 - accuracy: 0.9913 - val_loss: 0.0271 - val_accuracy: 0.9964
# Epoch 33/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0158 - accuracy: 0.9960 - val_loss: 0.2392 - val_accuracy: 0.9714
# Epoch 34/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0257 - accuracy: 0.9933 - val_loss: 0.0201 - val_accuracy: 0.9893
# Epoch 35/100
# 79/79 [==============================] - 1s 11ms/step - loss: 0.0248 - accuracy: 0.9933 - val_loss: 0.0458 - val_accuracy: 0.9857
# Epoch 36/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0061 - accuracy: 0.9988 - val_loss: 0.0517 - val_accuracy: 0.9857
# Epoch 37/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0067 - accuracy: 0.9968 - val_loss: 0.0108 - val_accuracy: 0.9964
# Epoch 38/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0121 - accuracy: 0.9964 - val_loss: 0.0488 - val_accuracy: 0.9893
# Epoch 39/100
# 79/79 [==============================] - 1s 11ms/step - loss: 0.0279 - accuracy: 0.9937 - val_loss: 0.0078 - val_accuracy: 0.9964
# Epoch 40/100
# 79/79 [==============================] - 1s 12ms/step - loss: 0.0170 - accuracy: 0.9944 - val_loss: 0.0541 - val_accuracy: 0.9786
# Epoch 41/100
# 79/79 [==============================] - 1s 11ms/step - loss: 0.0290 - accuracy: 0.9960 - val_loss: 0.1556 - val_accuracy: 0.9571
# Epoch 42/100
# 79/79 [==============================] - 1s 11ms/step - loss: 0.0268 - accuracy: 0.9917 - val_loss: 0.0261 - val_accuracy: 0.9893
# Epoch 43/100
# 79/79 [==============================] - 1s 11ms/step - loss: 0.0092 - accuracy: 0.9980 - val_loss: 0.0109 - val_accuracy: 0.9964
# Epoch 44/100
# 79/79 [==============================] - 1s 11ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0128 - val_accuracy: 0.9964
# Epoch 45/100
# 79/79 [==============================] - 1s 11ms/step - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.0323 - val_accuracy: 0.9964
# Epoch 46/100
# 79/79 [==============================] - 1s 10ms/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 0.0077 - val_accuracy: 0.9964
# Epoch 47/100
# 79/79 [==============================] - 1s 10ms/step - loss: 4.6689e-04 - accuracy: 1.0000 - val_loss: 0.0082 - val_accuracy: 0.9964
# Epoch 48/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.4234e-04 - accuracy: 1.0000 - val_loss: 0.0092 - val_accuracy: 0.9964
# Epoch 49/100
# 79/79 [==============================] - 1s 12ms/step - loss: 3.9699e-05 - accuracy: 1.0000 - val_loss: 0.0089 - val_accuracy: 0.9964
# Epoch 50/100
# 79/79 [==============================] - 1s 11ms/step - loss: 2.0627e-05 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9964
# Epoch 51/100
# 79/79 [==============================] - 1s 11ms/step - loss: 1.2944e-05 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 0.9964
# Epoch 52/100
# 79/79 [==============================] - 1s 11ms/step - loss: 9.4584e-06 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 0.9964
# Epoch 53/100
# 79/79 [==============================] - 1s 11ms/step - loss: 7.1078e-06 - accuracy: 1.0000 - val_loss: 0.0066 - val_accuracy: 0.9964
# Epoch 54/100
# 79/79 [==============================] - 1s 11ms/step - loss: 5.5299e-06 - accuracy: 1.0000 - val_loss: 0.0068 - val_accuracy: 0.9964
# Epoch 55/100
# 79/79 [==============================] - 1s 11ms/step - loss: 4.5727e-06 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 0.9964
# Epoch 56/100
# 79/79 [==============================] - 1s 12ms/step - loss: 3.8532e-06 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9964
# Epoch 57/100
# 79/79 [==============================] - 1s 12ms/step - loss: 3.2746e-06 - accuracy: 1.0000 - val_loss: 0.0067 - val_accuracy: 0.9964
# Epoch 58/100
# 79/79 [==============================] - 1s 11ms/step - loss: 2.7228e-06 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 0.9964
# Epoch 59/100
# 79/79 [==============================] - 1s 11ms/step - loss: 2.3179e-06 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 0.9964
# Epoch 60/100
# 79/79 [==============================] - 1s 11ms/step - loss: 1.9786e-06 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 0.9964
# Epoch 61/100
# 79/79 [==============================] - 1s 10ms/step - loss: 1.7037e-06 - accuracy: 1.0000 - val_loss: 0.0071 - val_accuracy: 0.9964
# Epoch 62/100
# 79/79 [==============================] - 1s 11ms/step - loss: 1.5027e-06 - accuracy: 1.0000 - val_loss: 0.0074 - val_accuracy: 0.9964
# Epoch 63/100
# 79/79 [==============================] - 1s 13ms/step - loss: 1.3103e-06 - accuracy: 1.0000 - val_loss: 0.0073 - val_accuracy: 0.9964
# Epoch 64/100
# 79/79 [==============================] - 1s 12ms/step - loss: 1.1768e-06 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9964
# Epoch 65/100
# 79/79 [==============================] - 1s 14ms/step - loss: 1.0455e-06 - accuracy: 1.0000 - val_loss: 0.0086 - val_accuracy: 0.9964
# Epoch 66/100
# 79/79 [==============================] - 1s 15ms/step - loss: 9.1858e-07 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 0.9964
# Epoch 67/100
# 79/79 [==============================] - 1s 15ms/step - loss: 8.2039e-07 - accuracy: 1.0000 - val_loss: 0.0094 - val_accuracy: 0.9964
# Epoch 68/100
# 79/79 [==============================] - 1s 15ms/step - loss: 7.4027e-07 - accuracy: 1.0000 - val_loss: 0.0090 - val_accuracy: 0.9964
# Epoch 69/100
# 79/79 [==============================] - 1s 15ms/step - loss: 6.7188e-07 - accuracy: 1.0000 - val_loss: 0.0087 - val_accuracy: 0.9964
# Epoch 70/100
# 79/79 [==============================] - 1s 15ms/step - loss: 6.3617e-07 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 0.9964
# Epoch 71/100
# 79/79 [==============================] - 1s 12ms/step - loss: 5.7231e-07 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 0.9964
# Epoch 72/100
# 79/79 [==============================] - 1s 11ms/step - loss: 5.1972e-07 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9964
# Epoch 73/100
# 79/79 [==============================] - 1s 11ms/step - loss: 4.8249e-07 - accuracy: 1.0000 - val_loss: 0.0100 - val_accuracy: 0.9964
# Epoch 74/100
# 79/79 [==============================] - 1s 11ms/step - loss: 4.4659e-07 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 0.9964
# Epoch 75/100
# 79/79 [==============================] - 1s 12ms/step - loss: 4.0917e-07 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9964
# Epoch 76/100
# 79/79 [==============================] - 1s 12ms/step - loss: 3.8708e-07 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9964
# Epoch 77/100
# 79/79 [==============================] - 1s 10ms/step - loss: 3.5638e-07 - accuracy: 1.0000 - val_loss: 0.0107 - val_accuracy: 0.9964
# Epoch 78/100
# 79/79 [==============================] - 1s 12ms/step - loss: 3.3661e-07 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 0.9964
# Epoch 79/100
# 79/79 [==============================] - 1s 12ms/step - loss: 3.2370e-07 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 0.9964
# Epoch 80/100
# 79/79 [==============================] - 1s 11ms/step - loss: 2.9120e-07 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 0.9964
# Epoch 81/100
# 79/79 [==============================] - 1s 11ms/step - loss: 2.7422e-07 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9964
# Epoch 82/100
# 79/79 [==============================] - 1s 12ms/step - loss: 2.5705e-07 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 0.9964
# Epoch 83/100
# 79/79 [==============================] - 1s 11ms/step - loss: 2.4016e-07 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9964
# Epoch 84/100
# 79/79 [==============================] - 1s 11ms/step - loss: 2.2455e-07 - accuracy: 1.0000 - val_loss: 0.0103 - val_accuracy: 0.9964
# Epoch 85/100
# 79/79 [==============================] - 1s 12ms/step - loss: 2.1069e-07 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 0.9964
# Epoch 86/100
# 79/79 [==============================] - 1s 12ms/step - loss: 2.0672e-07 - accuracy: 1.0000 - val_loss: 0.0098 - val_accuracy: 0.9964
# Epoch 87/100
# 79/79 [==============================] - 1s 11ms/step - loss: 1.8936e-07 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 0.9964
# Epoch 88/100
# 79/79 [==============================] - 1s 11ms/step - loss: 1.7867e-07 - accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 0.9964
# Epoch 89/100
# 79/79 [==============================] - 1s 11ms/step - loss: 1.6963e-07 - accuracy: 1.0000 - val_loss: 0.0105 - val_accuracy: 0.9964
# Epoch 90/100
# 79/79 [==============================] - 1s 11ms/step - loss: 1.6353e-07 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 0.9964

# %%
acc = [0.] + history.history['accuracy']
val_acc = [0.] + history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
